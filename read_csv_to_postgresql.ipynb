# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/dwku/Desktop/test.csv')
df.columns = [c.lower() for c in df.columns] #postgres doesn't like capitals or spaces

# %%
df.head()
# Out:
#    history_seq        history_transtime  history_areaid history_areaname  \
# 0      3689910  2018-08-17 20:33:43.680              17       R-Calender
# 1      3689911  2018-08-17 20:33:43.680              17       R-Calender
# 2      3689912  2018-08-17 20:33:43.680              17       R-Calender
# 3      3689913  2018-08-17 20:33:43.680              17       R-Calender
# 4      3689914  2018-08-17 20:33:43.680              17       R-Calender
#
#    history_machineid history_machinename  history_sensorid history_sensorname  \
# 0                 18   Dryer Drums Drive                19         Motor Body
# 1                 18   Dryer Drums Drive                19         Motor Body
# 2                 18   Dryer Drums Drive                19         Motor Body
# 3                 18   Dryer Drums Drive                19         Motor Body
# 4                 18   Dryer Drums Drive                19         Motor Body
#
# ...

# %%
len(df)
# Out:
# 2212836

# %%
import psycopg2

# %%
df = pd.read_csv('C:/Users/dwku/Downloads/data.csv')
df.head()
# Out:
#    history_seq           history_transtime  history_areaid history_areaname  \
# 0       194417  2018-12-19 13:37:53.188+09             596           8-Line
# 1       194418  2018-12-19 13:37:53.188+09             596           8-Line
# 2       194419  2018-12-19 13:37:53.188+09             596           8-Line
# 3       194420  2018-12-19 13:37:53.188+09             596           8-Line
# 4       194421  2018-12-19 13:37:53.188+09             596           8-Line
#
#    history_machineid history_machinename  history_sensorid history_sensorname  \
# 0                628                 박리단               631        박리단 UP/DOWN
# 1                628                 박리단               632           박리단 이행장치
# 2                628                 박리단               632           박리단 이행장치
# 3                628                 박리단               632           박리단 이행장치
# 4                633                 건조단               634        건조단 상부 이행모터
#
# ...

# %%
df = df.drop(['history_item_tag'], axis=1)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:welcome1@localhost:5432/postgres')

# %%
df.to_sql("historydata", engine ,if_exists='append', index=False)

# %%
# import pandas as pd
# import numpy as np
# import psycopg2
# from sqlalchemy import create_engine

# engine = create_engine('postgresql+psycopg2://postgres:welcome1@localhost:5432/postgres')

# df = pd.read_csv('local-file.csv', sep=',').replace(to_replace='null', value=np.NaN)
# df.to_sql('historydata', engine, schema='dbschema', if_exists='replace')
